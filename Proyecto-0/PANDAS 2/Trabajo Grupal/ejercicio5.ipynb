# %%
import pandas as pd
import numpy as np
# Cargamos un archivo CSV separado por punto y coma
data = pd.read_csv('data/student-mat.csv', index_col="internet")

# Leer las primeras 10 líneas
data.head()
# Out:
#          school sex  age address famsize Pstatus  Medu  Fedu     Mjob  \
# internet
# no           GP   F   18       U     GT3       A     4     4  at_home
# yes          GP   F   17       U     GT3       T     1     1  at_home
# yes          GP   F   15       U     LE3       T     1     1  at_home
# yes          GP   F   15       U     GT3       T     4     2   health
# no           GP   F   16       U     GT3       T     3     3    other
#
#               Fjob  ... famrel freetime  goout  Dalc  Walc health absences  \
# internet            ...
# no         teacher  ...      4        3      4     1     1      3        6
# yes          other  ...      5        3      3     1     1      3        4
# yes          other  ...      4        3      2     2     3      3       10
# yes       services  ...      3        2      2     1     1      5        2
# no           other  ...      4        3      2     1     2      5        4
#
#           G1  G2  G3
# internet
# no         5   6   6
# ...

# %%
data = pd.read_csv('data/student-mat.csv', index_col="internet")

# Filtrar y mostrar solo los alumnos que no tienen internet
students_no_internet = data.loc['no']
students_no_internet
# Out:
#          school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# internet
# no           GP   F   18       U     GT3       A     4     4   at_home
# no           GP   F   16       U     GT3       T     3     3     other
# no           GP   F   17       U     GT3       A     4     4     other
# no           GP   F   16       U     GT3       T     3     3     other
# no           GP   F   15       U     GT3       T     2     3     other
# ...         ...  ..  ...     ...     ...     ...   ...   ...       ...
# no           MS   M   18       R     GT3       T     4     2     other
# no           MS   F   18       R     GT3       T     2     2   at_home
# no           MS   F   18       U     GT3       T     1     1     other
# no           MS   M   20       U     LE3       A     2     2  services
# no           MS   M   21       R     GT3       T     1     1     other
#
#               Fjob  ... famrel freetime  goout  Dalc  Walc health absences  \
# internet            ...
# ...

# %%
# Guardar la información en un nuevo archivo CSV
students_no_internet.to_csv('student-internet.csv')
